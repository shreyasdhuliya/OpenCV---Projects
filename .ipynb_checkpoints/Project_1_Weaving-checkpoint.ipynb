# %%
from functions import *

# %% [markdown]
# # 1. Getting image

# %%
#asking for image path
img = get_image()
# Out:
# Enter the image path:ayu.jpg
# width of the image: 800  pixels
# height of the image: 1200  pixels

# %% [markdown]
# # 2. Adaptive step

# %% [markdown]
# ### 2.1 DISPLAYING THRESHOLD IMAGES: Getting various results of adaptive filters
#
# #### 1. **Run** the below code to get multiple results

# %%
show_mul_adap(img)

# %% [markdown]
# ### 2.2 Choose the filter size of your choice from Above image Titles
# #### Enter interger values :
# > ## NOTE: ODD NUMBER ONLY

# %%
#based on the above choose adaptive filter size
img_processed = perform_adap(img)
# Out:
# Enter enter filter size(should be odd number):411

# %% [markdown]
# # 3. MORPH CLOSE step

# %% [markdown]
# ### 3.1 DISPLAYING DIALATION IMAGES: Getting various results of iterations

# %%
show_morph_close(img_processed)

# %% [markdown]
# ### 3.2 CHOOSE THE DIALATION KERNAL and ITERATION
# > ### NOTE: ENTER NUMERICAL VALUE ONLY

# %%
img_processed =  perform_erosion(img_processed)
# Out:
# choice kernel type: 1. ellipse, 2. plus: 2
# 1-4: 1

# %% [markdown]
# # 4. CREATING WEAVE IMAGE

# %% [markdown]
# ### 4.1 Enter Warf and Weft Colors
#
# - Examples
#       - WARF (r,g,b) format: eg.100 100 255:0 112 145<br>
#        WEFT (r,g,b) format: eg.100 100 255:0 0 255
#
# > #### Note: Enter value between 0-255

# %%
show_create_weave(img_processed)
# Out:
# WARF (r,g,b) format: eg.100 100 255:25 165 218
# WEFT (r,g,b) format: eg.100 100 255:20 20 20
# Enter Weft width(integer):5
# Enter Warf width(integer):6
# number of warf:160 and weft:200:

# %% [markdown]
# # Perform Weave and Save image

# %%
perform_create_weave(img_processed)
# Out:
# WARF (r,g,b) format: eg.100 100 255:25 165 218
# WEFT (r,g,b) format: eg.100 100 255:20 20 20
# Enter Weft width(integer):10
# Enter Warf width(integer):12
# number of warf:80 and weft:100:
# Enter thresh(integer) [0 -255]:100
# Write the image name you want to save it as(example: weave_1)100_80_411
