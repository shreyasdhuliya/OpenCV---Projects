# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
black = np.zeros([900,900],'uint8')

# %%
plt.imshow(black, cmap = 'gray')

# %%
nu = input("enter the first circle speed(int):")
de = input("enter the second circle speed(int):")
numinator = int(nu)*1000
denominator = int(de)*1000
# Out:
# enter the first circle speed(int):3
# enter the second circle speed(int):2

# %%
angles_nu = np.deg2rad(np.linspace(0,360,numinator, endpoint = False))
angles_de = np.deg2rad(np.linspace(0,360,denominator, endpoint = False))

# %%
len(angles_de)
# Out:
# 2000

# %%
x1 = 100*np.cos(angles_nu)
x1 = np.round(x1) + 200
x2 = 100*np.cos(angles_de)
x2 = np.round(x2) + 500

# %%
y1 = 100*np.sin(angles_nu)
y1 = np.round(y1) + 200
y2 = 100*np.sin(angles_de)
y2 = np.round(y2) + 500

# %%
y_p1 = list(y2)*int(nu)
x_p1 = list(x1)*int(de)
y_p2 = list(y1)*int(de)
x_p2 = list(x2)*int(nu)

# %%
len(x_p2)
# Out:
# 6000

# %%
for i in range(len(y_p)):
        black[int(x_p1[i]),int(y_p1[i])] = 255
        black[int(x_p2[i]),int(y_p2[i])] = 255

# %%
fig = plt.figure(figsize = (36, 36)) 
plt.imshow(black, cmap = 'gray')
